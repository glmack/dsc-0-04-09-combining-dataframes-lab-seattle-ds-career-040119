# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, we'll gain practice combining DataFrames through concatenation.  We'll also learn to read in tables from a database and store them in separate tables, as well as how to execute various types of joins to selectively combine the information stored in the tables!
#
#
# ## Objectives:
# You will be able to:
# * Understand and explain when to use DataFrame joins and merges
# * Be able to use pd.merge when combining DataFrames based on column values
# * Understand, explain and use a range of DataFrame merge types: outer, inner, left and right
# * Use pd.concat() to stack DataFrames
#
# ## Getting Started
#
# We'll start with a quick section to help us gain practice with concatenating datasets using `pd.concat()`.
#
# ### Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that we have multiple DataFrames to work with, we can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
combined_df = pd.concat([df1, df2, df3])
combined_df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="er1.png">
#
# ### Setting Join Conditions With Concatenation
#
# We can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, we'll execute an inner join. Before we do, we need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` method to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 = None
df1_and_4 = pd.concat([df1, df4], join='inner', axis=1)

df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='er2.png'>
#
# We'll notice that in this case, the results returned contain only the rows with indexes that exist in both tables--rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that we can make full use of the `concat()` functionality in pandas to join DataFrames together--these are just a few of the most common examples pulled from the pandas documentation on the subject.  For a full view of all the ways we can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!

# %% [markdown]
# ## Loading In Data From SQL Database Tables
#
# Now, we'll move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the  [kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table--but not all--correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  We'll make use of these keys to **_join_** the different tables together into a single DataFrame.  We'll also experiment with different types of joins to help us decide exactly what information we want to combine.
#
# Before we can begin working with the database, we'll first need to connect to it.  For this, we'll use the `sqlalchemy` library.
#
# In the cell below:
#
# * Import the `create_engine` module from `sqlalchemy`
# * Create an engine that connects to `sqlite:///database.sqlite`.

# %%
from sqlalchemy import create_engine

# creates engine object
engine = create_engine('sqlite:///database.sqlite')

# %%
engine
# Out:
# Engine(sqlite:///database.sqlite)

# %% [markdown]
# Now that we've successfully connected to our Database, we'll make use of pandas to read in each table individually.
#
# In the cell below, read in each sql table into separate pandas DataFrames using the `read_sql_table` method.
#
# The first argument should be a string corresponding to the name of the table, and the second argument should be the `engine` object we created in the cell above.
#
# If you're unsure of how to do this, see the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html).

# %%
# Lee - ???
cards_df = pd.read_sql_table('cards', engine)

# %%
len(cards_df)
# Out:
# 2819

# %%
cards_df
# Out:
#                             card_id player_class         type  \
# 0                        KARA_00_07         MAGE        SPELL
# 1                         NEW1_008a        DRUID        SPELL
# 2                         BRM_010t2        DRUID       MINION
# 3                            AT_132      NEUTRAL       MINION
# 4                            OG_141      NEUTRAL       MINION
# 5                           CRED_17      NEUTRAL       MINION
# 6                           OG_337e      NEUTRAL  ENCHANTMENT
# 7                         BRMA08_1H      NEUTRAL         HERO
# 8                          GVG_011a      NEUTRAL  ENCHANTMENT
# 9                       NAX8_02H_TB      NEUTRAL   HERO_POWER
# 10                           AT_131      NEUTRAL       MINION
# 11                         CS2_122e      NEUTRAL  ENCHANTMENT
# 12                      LOEA05_02ha      NEUTRAL   HERO_POWER
# 13                CS2_102_H1_AT_132      WARRIOR   HERO_POWER
# 14                         CFM_334e      NEUTRAL  ENCHANTMENT
# 15                          EX1_583      NEUTRAL       MINION
# 16           TB_PickYourFate_11rand      NEUTRAL        SPELL
# 17                         LOE_007t      WARLOCK        SPELL
# 18                          CFM_095      NEUTRAL       MINION
# 19                          BRM_018      PALADIN       MINION
# 20                         PRO_001a      NEUTRAL        SPELL
# 21                        BRMA10_5H      NEUTRAL       MINION
# 22                         BRMA11_1      NEUTRAL         HERO
# 23                           OG_027       SHAMAN        SPELL
# 24                          NAX1_01      NEUTRAL         HERO
# 25                          GVG_030        DRUID       MINION
# 26                          CFM_094      WARLOCK        SPELL
# 27                      DS1h_292_H1       HUNTER   HERO_POWER
# 28                          CS2_227      NEUTRAL       MINION
# 29                          KAR_062      NEUTRAL       MINION
# ...                             ...          ...          ...
# 2789                       LOEA12_2      NEUTRAL   HERO_POWER
# 2790                         AT_084      NEUTRAL       MINION
# 2791                     KARA_00_03         MAGE         HERO
# 2792                       BRMA16_3      NEUTRAL        SPELL
# 2793                        tt_010a         MAGE       MINION
# 2794                        EX1_559         MAGE       MINION
# 2795                        EX1_624       PRIEST        SPELL
# 2796                        OG_044a        DRUID       MINION
# 2797                         AT_044        DRUID        SPELL
# 2798                  AT_132_SHAMAN       SHAMAN   HERO_POWER
# 2799                     CFM_621t29      NEUTRAL        SPELL
# 2800                       EX1_355e      PALADIN  ENCHANTMENT
# 2801                      LOEA09_3d      NEUTRAL   HERO_POWER
# 2802                  TB_Coopv3_105      NEUTRAL       MINION
# 2803                       BRMA13_4      NEUTRAL   HERO_POWER
# 2804                       EX1_345t       PRIEST       MINION
# 2805                        EX1_009      NEUTRAL       MINION
# 2806                        CRED_32      NEUTRAL       MINION
# 2807                       FP1_030e      NEUTRAL  ENCHANTMENT
# 2808        TB_PickYourFate_10_Ench      NEUTRAL  ENCHANTMENT
# 2809             KARA_05_01hpheroic      NEUTRAL   HERO_POWER
# 2810                       BRMA10_3      NEUTRAL   HERO_POWER
# 2811  TB_PickYourFate_10_EnchMinion      NEUTRAL  ENCHANTMENT
# 2812                       NAX3_02H      NEUTRAL   HERO_POWER
# 2813                        AT_083e      NEUTRAL  ENCHANTMENT
# 2814                        AT_066e      WARRIOR  ENCHANTMENT
# 2815                        CS2_031         MAGE        SPELL
# 2816                        OG_195e      NEUTRAL  ENCHANTMENT
# 2817                       XXX_111e      NEUTRAL  ENCHANTMENT
# 2818                        NAX3_01      NEUTRAL         HERO
#
#                                         name         set  \
# 0                              Astral Portal        KARA
# 1                          Ancient Teachings     EXPERT1
# 2                         Druid of the Flame         BRM
# 3                         Justicar Trueheart         TGT
# 4                          Faceless Behemoth          OG
# 5                                  Rob Pardo     CREDITS
# 6                         Eve of Destruction          OG
# 7                         General Drakkisath         BRM
# 8                                 Shrink Ray         GVG
# 9                                    Harvest          TB
# 10                            Eydis Darkbane         TGT
# 11                                  Enhanced        CORE
# 12                       Trogg Hate Minions!         LOE
# 13                                  Tank Up!  HERO_SKINS
# 14                                 Smuggling       GANGS
# 15                        Priestess of Elune     EXPERT1
# 16                        Dire Fate: Murlocs          TB
# 17                                   Cursed!         LOE
# 18                           Weasel Tunneler       GANGS
# 19                            Dragon Consort         BRM
# 20                               I Am Murloc       PROMO
# 21                           Chromatic Drake         BRM
# 22                   Vaelastrasz the Corrupt         BRM
# 23                                    Evolve          OG
# 24                               Anub'Rekhan        NAXX
# 25                         Anodized Robo Cub         GVG
# 26                            Felfire Potion       GANGS
# 27                               Steady Shot  HERO_SKINS
# 28                     Venture Co. Mercenary     EXPERT1
# 29                     Netherspite Historian        KARA
# ...                                      ...         ...
# 2789                      Pearl of the Tides         LOE
# 2790                           Lance Carrier         TGT
# 2791                                  Medivh        KARA
# 2792                            Sonic Breath         BRM
# 2793                             Spellbender     EXPERT1
# 2794                      Archmage Antonidas     EXPERT1
# 2795                               Holy Fire     EXPERT1
# 2796                       Druid of the Claw     EXPERT1
# 2797                                   Mulch         TGT
# 2798                            Totemic Slam         TGT
# 2799                             Mystic Wool       GANGS
# 2800                        Blessed Champion     EXPERT1
# 2801                          Getting Hungry         LOE
# 2802                             Raid Healer          TB
# 2803                              Wild Magic         BRM
# 2804                       Shadow of Nothing     EXPERT1
# 2805                           Angry Chicken     EXPERT1
# 2806                            Jerry Mascho     CREDITS
# 2807                           Necrotic Aura        NAXX
# 2808                                    Fate          TB
# 2809                               Trembling        KARA
# 2810                             The Rookery         BRM
# 2811                                   Bonus          TB
# 2812                                Web Wrap        NAXX
# 2813                           Dragonhawkery         TGT
# 2814                     Forges of Orgrimmar         TGT
# 2815                               Ice Lance     EXPERT1
# 2816                                Enormous          OG
# 2817  All Charge, All Windfury, All The Time       CHEAT
# 2818                                 Maexxna        NAXX
#
#                                                    text  cost  attack  health  \
# 0              Summon a random <b>Legendary</b> minion.   1.0     NaN     NaN
# 1                                          Draw a card.   0.0     NaN     NaN
# 2                                                  None   3.0     2.0     5.0
# 3     <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0     3.0
# 4                                                  None  10.0    10.0    10.0
# 5     You can't start a game without this minion in ...   9.0     9.0     9.0
# 6                                      Stats increased.   NaN     NaN     NaN
# 7                                                  None   NaN     NaN    50.0
# 8                                  -2 Attack this turn.   NaN     NaN     NaN
# 9     <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...   2.0     NaN     NaN
# 10    Whenever <b>you</b> target this minion with a ...   3.0     3.0     4.0
# 11       Raid Leader is granting this minion +1 Attack.   NaN     NaN     NaN
# 12    <b>Passive Hero Power</b>\n Enemy minions cost...   0.0     NaN     NaN
# 13                     <b>Hero Power</b>\nGain 4 Armor.   2.0     NaN     NaN
# 14                         +2/+2 from Smuggler's Crate.   NaN     NaN     NaN
# 15     <b>Battlecry:</b> Restore 4 Health to your hero.   6.0     5.0     4.0
# 16          Turn each minion in play into a 1/1 Murloc.   0.0     NaN     NaN
# 17    While this is in your hand, take 2 damage at t...   2.0     NaN     NaN
# 18    <b>Deathrattle:</b> Shuffle this minion into y...   1.0     1.0     1.0
# 19    <b>Battlecry:</b> The next Dragon you play cos...   5.0     5.0     5.0
# 20             Summon three, four, or five 1/1 Murlocs.   4.0     NaN     NaN
# 21                                                 None   4.0     7.0     7.0
# 22                                                 None   NaN     NaN    30.0
# 23    Transform your minions into random minions tha...   1.0     NaN     NaN
# 24                                                 None   NaN     NaN    30.0
# 25    <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0     2.0     2.0
# 26                    Deal $5 damage to all characters.   6.0     NaN     NaN
# 27    <b>Hero Power</b>\nDeal $2 damage to the enemy...   2.0     NaN     NaN
# 28                          Your minions cost (3) more.   5.0     7.0     6.0
# 29    <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     1.0     3.0
# ...                                                 ...   ...     ...     ...
# 2789  At the end of your turn, replace all minions w...   0.0     NaN     NaN
# 2790  <b>Battlecry:</b> Give a friendly minion +2 At...   2.0     1.0     2.0
# 2791                                               None   NaN     NaN    30.0
# 2792  Deal $3 damage to a minion. Give your weapon +...   4.0     NaN     NaN
# 2793                                               None   1.0     1.0     3.0
# 2794  Whenever you cast a spell, add a 'Fireball' sp...   7.0     5.0     7.0
# 2795    Deal $5 damage. Restore #5 Health to your hero.   6.0     NaN     NaN
# 2796                        <b>Charge</b>\n<b>Taunt</b>   5.0     4.0     6.0
# 2797  Destroy a minion.\nAdd a random minion to your...   3.0     NaN     NaN
# 2798  <b>Hero Power</b>\nSummon a Totem of your choice.   2.0     NaN     NaN
# 2799              Transform all minions into 1/1 Sheep.  10.0     NaN     NaN
# 2800             This minion's Attack has been doubled.   NaN     NaN     NaN
# 2801       <b>Hero Power</b>\nSummon a 5/1 Hungry Naga.   0.0     NaN     NaN
# 2802  Whenever your hero is healed, also heal your t...   4.0     0.0     7.0
# 2803  <b>Hero Power</b>\nPut a random spell from you...   1.0     NaN     NaN
# 2804   Mindgames whiffed! Your opponent had no minions!   0.0     0.0     1.0
# 2805                          <b>Enrage:</b> +5 Attack.   1.0     1.0     1.0
# 2806  At the start of your turn, deal 1 damage. If t...   2.0     3.0     2.0
# 2807               Your spells cost (5) more this turn.   NaN     NaN     NaN
# 2808                                               None   NaN     NaN     NaN
# 2809  <b>Passive Hero Power</b> Minions cost (1). En...   0.0     NaN     NaN
# 2810  <b>Hero Power</b>\nGive all Corrupted Eggs +1 ...   1.0     NaN     NaN
# 2811          Your <b>Battlecry</b> minions have +1/+1.   NaN     NaN     NaN
# 2812  <b>Hero Power</b>\nReturn 2 random enemy minio...   0.0     NaN     NaN
# 2813                         <b>Windfury</b> this turn.   NaN     NaN     NaN
# 2814                                  Increased Attack.   NaN     NaN     NaN
# 2815  <b>Freeze</b> a character. If it was already <...   1.0     NaN     NaN
# 2816                                             +2/+2.   NaN     NaN     NaN
# 2817  Your minions always have <b>Charge</b> and <b>...   NaN     NaN     NaN
# 2818                                               None   NaN     NaN    30.0
#
#          rarity  collectible  \
# 0          None          NaN
# 1          None          NaN
# 2        COMMON          NaN
# 3     LEGENDARY          1.0
# 4        COMMON          1.0
# 5     LEGENDARY          NaN
# 6          None          NaN
# 7          None          NaN
# 8          None          NaN
# 9          None          NaN
# 10    LEGENDARY          1.0
# 11         None          NaN
# 12         None          NaN
# 13         None          NaN
# 14         None          NaN
# 15       COMMON          1.0
# 16         None          NaN
# 17         None          NaN
# 18         EPIC          1.0
# 19         RARE          1.0
# 20         None          NaN
# 21         None          NaN
# 22         None          NaN
# 23         RARE          1.0
# 24         None          NaN
# 25       COMMON          1.0
# 26         RARE          1.0
# 27         FREE          NaN
# 28       COMMON          1.0
# 29       COMMON          1.0
# ...         ...          ...
# 2789       None          NaN
# 2790     COMMON          1.0
# 2791       None          NaN
# 2792       None          NaN
# 2793       EPIC          NaN
# 2794  LEGENDARY          1.0
# 2795       RARE          1.0
# 2796     COMMON          NaN
# 2797       EPIC          1.0
# 2798       None          NaN
# 2799       None          NaN
# 2800       None          NaN
# 2801       None          NaN
# 2802       None          NaN
# 2803       None          NaN
# 2804       EPIC          NaN
# 2805       RARE          1.0
# 2806  LEGENDARY          NaN
# 2807       None          NaN
# 2808       None          NaN
# 2809     COMMON          NaN
# 2810       None          NaN
# 2811       None          NaN
# 2812       None          NaN
# 2813       None          NaN
# 2814       None          NaN
# 2815     COMMON          1.0
# 2816       None          NaN
# 2817       None          NaN
# 2818       None          NaN
#
#                                                  flavor        race  \
# 0                                                  None        None
# 1                                                  None        None
# 2                                                  None       BEAST
# 3     It's like putting racing stripes and a giant s...        None
# 4     Rejected names: Forty-Foot Faceless, Big ol' N...        None
# 5                                                  None        None
# 6                                                  None        None
# 7                                                  None        None
# 8                                                  None        None
# 9                                                  None        None
# 10               HATES being called "the wonder twins".        None
# 11                                                 None        None
# 12                                                 None        None
# 13                                                 None        None
# 14                                                 None        None
# 15    If she threatens to "moon" you, it's not what ...        None
# 16                                                 None        None
# 17                                                 None        None
# 18    He's the reason the First Bank of Gadgetzan ha...       BEAST
# 19    Everybody wants someone to snuggle with. Even ...      DRAGON
# 20                                                 None        None
# 21                                                 None      DRAGON
# 22                                                 None        None
# 23    So you say you want an evolution. Well, you kn...        None
# 24                                                 None        None
# 25    It's adorable! AND OH MY GOODNESS WHY IS IT EA...  MECHANICAL
# 26    Kazakus has a squad of imps bottling Felfire r...        None
# 27                                                 None        None
# 28               No Job is too big.  No fee is too big.        None
# 29    She can tell you all about the history of peop...        None
# ...                                                 ...         ...
# 2789                                               None        None
# 2790  Lance Carrier is an obscure entry level positi...        None
# 2791                                               None        None
# 2792                                               None        None
# 2793                                               None        None
# 2794  Antonidas was the Grand Magus of the Kirin Tor...        None
# 2795                     Often followed by Holy Smokes!        None
# 2796                                               None       BEAST
# 2797     Is this a noun or a verb?  We will never know.        None
# 2798                                               None        None
# 2799                                               None        None
# 2800                                               None        None
# 2801                                               None        None
# 2802                                               None        None
# 2803                                               None        None
# 2804                                               None        None
# 2805  There is no beast more frightening (or ridicul...       BEAST
# 2806                                               None        None
# 2807                                               None        None
# 2808                                               None        None
# 2809                                               None        None
# 2810                                               None        None
# 2811                                               None        None
# 2812                                               None        None
# 2813                                               None        None
# 2814                                               None        None
# 2815  The trick is not to break the lance.  Otherwis...        None
# 2816                                               None        None
# 2817                                               None        None
# 2818                                               None        None
#
#                                             how_to_earn  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19    Unlocked in Blackrock Spire, in the Blackrock ...
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29     Unlocked in the Spire, in One Night in Karazhan.
# ...                                                 ...
# 2789                                               None
# 2790                                               None
# 2791                                               None
# 2792                                               None
# 2793                                               None
# 2794                                               None
# 2795                                               None
# 2796                                               None
# 2797                                               None
# 2798                                               None
# 2799                                               None
# 2800                                               None
# 2801                                               None
# 2802                                               None
# 2803                                               None
# 2804                                               None
# 2805                                               None
# 2806                                               None
# 2807                                               None
# 2808                                               None
# 2809                                               None
# 2810                                               None
# 2811                                               None
# 2812                                               None
# 2813                                               None
# 2814                                               None
# 2815                                               None
# 2816                                               None
# 2817                                               None
# 2818                                               None
#
#                                      how_to_earn_golden targeting_arrow_text  \
# 0                                                  None                 None
# 1                                                  None                 None
# 2                                                  None                 None
# 3                                                  None                 None
# 4                                                  None                 None
# 5                                                  None                 None
# 6                                                  None                 None
# 7                                                  None                 None
# 8                                                  None                 None
# 9                                                  None                 None
# 10                                                 None                 None
# 11                                                 None                 None
# 12                                                 None                 None
# 13                                                 None                 None
# 14                                                 None                 None
# 15                                                 None                 None
# 16                                                 None                 None
# 17                                                 None                 None
# 18                                                 None                 None
# 19    Crafting unlocked in Blackrock Spire, in the B...                 None
# 20                                                 None                 None
# 21                                                 None                 None
# 22                                                 None                 None
# 23                                                 None                 None
# 24                                                 None                 None
# 25                                                 None                 None
# 26                                                 None                 None
# 27                                                 None                 None
# 28                                                 None                 None
# 29    Crafting unlocked in the Spire, in One Night i...                 None
# ...                                                 ...                  ...
# 2789                                               None                 None
# 2790                                               None      Give +2 Attack.
# 2791                                               None                 None
# 2792                                               None                 None
# 2793                                               None                 None
# 2794                                               None                 None
# 2795                                               None                 None
# 2796                                               None                 None
# 2797                                               None                 None
# 2798                                               None                 None
# 2799                                               None                 None
# 2800                                               None                 None
# 2801                                               None                 None
# 2802                                               None                 None
# 2803                                               None                 None
# 2804                                               None                 None
# 2805                                               None                 None
# 2806                                               None                 None
# 2807                                               None                 None
# 2808                                               None                 None
# 2809                                               None                 None
# 2810                                               None                 None
# 2811                                               None                 None
# 2812                                               None                 None
# 2813                                               None                 None
# 2814                                               None                 None
# 2815                                               None                 None
# 2816                                               None                 None
# 2817                                               None                 None
# 2818                                               None                 None
#
#      faction  durability
# 0       None         NaN
# 1       None         NaN
# 2       None         NaN
# 3       None         NaN
# 4       None         NaN
# 5       None         NaN
# 6       None         NaN
# 7       None         NaN
# 8       None         NaN
# 9       None         NaN
# 10      None         NaN
# 11      None         NaN
# 12      None         NaN
# 13      None         NaN
# 14      None         NaN
# 15      None         NaN
# 16      None         NaN
# 17      None         NaN
# 18      None         NaN
# 19      None         NaN
# 20      None         NaN
# 21      None         NaN
# 22      None         NaN
# 23      None         NaN
# 24      None         NaN
# 25      None         NaN
# 26      None         NaN
# 27      None         NaN
# 28     HORDE         NaN
# 29      None         NaN
# ...      ...         ...
# 2789    None         NaN
# 2790    None         NaN
# 2791    None         NaN
# 2792    None         NaN
# 2793    None         NaN
# 2794    None         NaN
# 2795    None         NaN
# 2796    None         NaN
# 2797    None         NaN
# 2798    None         NaN
# 2799    None         NaN
# 2800    None         NaN
# 2801    None         NaN
# 2802    None         NaN
# 2803    None         NaN
# 2804    None         NaN
# 2805    None         NaN
# 2806    None         NaN
# 2807    None         NaN
# 2808    None         NaN
# 2809    None         NaN
# 2810    None         NaN
# 2811    None         NaN
# 2812    None         NaN
# 2813    None         NaN
# 2814    None         NaN
# 2815    None         NaN
# 2816    None         NaN
# 2817    None         NaN
# 2818    None         NaN
#
# [2819 rows x 18 columns]

# %%
dust_df = pd.read_sql_table('dust_costs', engine)

# %%
len(dust_df)
# Out:
# 4040

# %%
dust_df
# Out:
#         card_id             action  cost
# 0     BRM_010t2    CRAFTING_NORMAL    40
# 1     BRM_010t2    CRAFTING_GOLDEN   400
# 2     BRM_010t2  DISENCHANT_NORMAL     5
# 3     BRM_010t2  DISENCHANT_GOLDEN    50
# 4        AT_132    CRAFTING_NORMAL  1600
# 5        AT_132    CRAFTING_GOLDEN  3200
# 6        AT_132  DISENCHANT_NORMAL   400
# 7        AT_132  DISENCHANT_GOLDEN  1600
# 8        OG_141    CRAFTING_NORMAL    40
# 9        OG_141    CRAFTING_GOLDEN   400
# 10       OG_141  DISENCHANT_NORMAL     5
# 11       OG_141  DISENCHANT_GOLDEN    50
# 12       AT_131    CRAFTING_NORMAL  1600
# 13       AT_131    CRAFTING_GOLDEN  3200
# 14       AT_131  DISENCHANT_NORMAL   400
# 15       AT_131  DISENCHANT_GOLDEN  1600
# 16      EX1_583    CRAFTING_NORMAL    40
# 17      EX1_583    CRAFTING_GOLDEN   400
# 18      EX1_583  DISENCHANT_NORMAL     5
# 19      EX1_583  DISENCHANT_GOLDEN    50
# 20      CFM_095    CRAFTING_NORMAL   400
# 21      CFM_095    CRAFTING_GOLDEN  1600
# 22      CFM_095  DISENCHANT_NORMAL   100
# 23      CFM_095  DISENCHANT_GOLDEN   400
# 24      BRM_018    CRAFTING_NORMAL   100
# 25      BRM_018    CRAFTING_GOLDEN   800
# 26      BRM_018  DISENCHANT_NORMAL    20
# 27      BRM_018  DISENCHANT_GOLDEN   100
# 28       OG_027    CRAFTING_NORMAL   100
# 29       OG_027    CRAFTING_GOLDEN   800
# ...         ...                ...   ...
# 4010    tt_010a  DISENCHANT_NORMAL   100
# 4011    tt_010a  DISENCHANT_GOLDEN   400
# 4012    EX1_559    CRAFTING_NORMAL  1600
# 4013    EX1_559    CRAFTING_GOLDEN  3200
# 4014    EX1_559  DISENCHANT_NORMAL   400
# 4015    EX1_559  DISENCHANT_GOLDEN  1600
# 4016    EX1_624    CRAFTING_NORMAL   100
# 4017    EX1_624    CRAFTING_GOLDEN   800
# 4018    EX1_624  DISENCHANT_NORMAL    20
# 4019    EX1_624  DISENCHANT_GOLDEN   100
# 4020    OG_044a    CRAFTING_NORMAL    40
# 4021    OG_044a    CRAFTING_GOLDEN   400
# 4022    OG_044a  DISENCHANT_NORMAL     5
# 4023    OG_044a  DISENCHANT_GOLDEN    50
# 4024     AT_044    CRAFTING_NORMAL   400
# 4025     AT_044    CRAFTING_GOLDEN  1600
# 4026     AT_044  DISENCHANT_NORMAL   100
# 4027     AT_044  DISENCHANT_GOLDEN   400
# 4028   EX1_345t    CRAFTING_NORMAL   400
# 4029   EX1_345t    CRAFTING_GOLDEN  1600
# 4030   EX1_345t  DISENCHANT_NORMAL   100
# 4031   EX1_345t  DISENCHANT_GOLDEN   400
# 4032    EX1_009    CRAFTING_NORMAL   100
# 4033    EX1_009    CRAFTING_GOLDEN   800
# 4034    EX1_009  DISENCHANT_NORMAL    20
# 4035    EX1_009  DISENCHANT_GOLDEN   100
# 4036    CS2_031    CRAFTING_NORMAL    40
# 4037    CS2_031    CRAFTING_GOLDEN   400
# 4038    CS2_031  DISENCHANT_NORMAL     5
# 4039    CS2_031  DISENCHANT_GOLDEN    50
#
# [4040 rows x 3 columns]

# %%
entourages_df = pd.read_sql_table('entourages', engine)

# %%
len(entourages_df)
# Out:
# 328

# %%
entourages_df
# Out:
#                     card_id       entourage_card_id
# 0                KAR_A10_22              KAR_A10_09
# 1                KAR_A10_22              KAR_A10_02
# 2                KAR_A10_22              KAR_A10_08
# 3                KAR_A10_22              KAR_A10_04
# 4                KAR_A10_22              KAR_A10_05
# 5                  TBST_006                TBST_003
# 6                  TBST_006                TBST_002
# 7                  TBST_006                TBST_001
# 8                BRMA14_10H                BRMA14_3
# 9                BRMA14_10H               BRMA14_5H
# 10               BRMA14_10H               BRMA14_7H
# 11               BRMA14_10H               BRMA14_9H
# 12                 BRMA09_3                BRMA09_2
# 13                 BRMA09_3                BRMA09_4
# 14                 BRMA09_3                BRMA09_5
# 15             KARA_06_03hp              KARA_06_01
# 16                 BRMA12_2                BRMA12_6
# 17                 BRMA12_2                BRMA12_5
# 18                 BRMA12_2                BRMA12_7
# 19                 BRMA12_2                BRMA12_4
# 20                 BRMA12_2                BRMA12_3
# 21      TB_PickYourFate_2nd       TB_PickYourFate_1
# 22      TB_PickYourFate_2nd       TB_PickYourFate_4
# 23      TB_PickYourFate_2nd   TB_PickYourFate_7_2nd
# 24      TB_PickYourFate_2nd       TB_PickYourFate_3
# 25      TB_PickYourFate_2nd   TB_PickYourFate_6_2nd
# 26      TB_PickYourFate_2nd  TB_PickYourFate_11rand
# 27                   TB_001               BRMA14_10
# 28                   TB_001              BRMA14_10H
# 29                   TB_001                BRMA09_4
# ..                      ...                     ...
# 298              LOEA16_16H               LOEA16_10
# 299              LOEA16_16H               LOEA16_11
# 300              LOEA16_16H               LOEA16_14
# 301              LOEA16_16H               LOEA16_15
# 302              LOEA16_16H                LOEA16_6
# 303              LOEA16_16H                LOEA16_7
# 304              LOEA16_16H                LOEA16_9
# 305              LOEA16_16H               LOEA16_12
# 306              LOEA16_16H               LOEA16_13
# 307              LOEA16_16H                LOEA16_8
# 308                  TBUD_1                 CS1_042
# 309                  TBUD_1                 CS2_171
# 310               BRMA13_3H                BRMA13_8
# 311               BRMA13_3H                BRMA13_7
# 312               BRMA13_3H                BRMA13_6
# 313               BRMA13_3H                BRMA13_5
# 314  TB_MechWar_CommonCards                 GVG_069
# 315  TB_MechWar_CommonCards                 GVG_079
# 316  TB_MechWar_CommonCards                 GVG_034
# 317  TB_MechWar_CommonCards                 GVG_048
# 318  TB_MechWar_CommonCards                 GVG_049
# 319  TB_MechWar_CommonCards                 GVG_088
# 320              KARA_00_10                 EX1_294
# 321              KARA_00_10                 FP1_018
# 322              KARA_00_10                  AT_002
# 323              KARA_00_10                 EX1_287
# 324              KARA_00_10                  tt_010
# 325              KARA_00_10                 EX1_295
# 326              KARA_00_10                 EX1_289
# 327              KARA_00_10                 EX1_594
#
# [328 rows x 2 columns]

# %%
mechanics_df = pd.read_sql_table('mechanics', engine)

# %%
len(mechanics_df)
# Out:
# 1079

# %%
mechanics_df
# Out:
#                  card_id             mechanic
# 0                 AT_132            BATTLECRY
# 1               GVG_011a  TAG_ONE_TURN_EFFECT
# 2                EX1_583            BATTLECRY
# 3               LOE_007t            EVIL_GLOW
# 4               LOE_007t   ImmuneToSpellpower
# 5                CFM_095          DEATHRATTLE
# 6                BRM_018            BATTLECRY
# 7                GVG_030           CHOOSE_ONE
# 8                GVG_030                TAUNT
# 9                CS2_227                 AURA
# 10               KAR_062            BATTLECRY
# 11           CFM_712_t17           JADE_GOLEM
# 12              BRM_011t  TAG_ONE_TURN_EFFECT
# 13             BRMA10_3H         AI_MUST_PLAY
# 14              KAR_710m                TAUNT
# 15              EX1_295o  TAG_ONE_TURN_EFFECT
# 16                OG_158          DEATHRATTLE
# 17              LOE_110t              TOPDECK
# 18              LOE_110t   ImmuneToSpellpower
# 19             BRMA13_4H         AI_MUST_PLAY
# 20              EX1_145o  TAG_ONE_TURN_EFFECT
# 21             LOEA09_2e  TAG_ONE_TURN_EFFECT
# 22              EX1_570e  TAG_ONE_TURN_EFFECT
# 23               GVG_069            BATTLECRY
# 24               hexfrog                TAUNT
# 25                OG_145        DIVINE_SHIELD
# 26                OG_145                TAUNT
# 27                AT_090              INSPIRE
# 28                AT_060               SECRET
# 29    TB_MechWar_Minion1                TAUNT
# ...                  ...                  ...
# 1049             EX1_284            BATTLECRY
# 1050             LOE_038                 AURA
# 1051              AT_083              INSPIRE
# 1052    TB_CoOpv3_BOSS2e              ENRAGED
# 1053             GVG_009            BATTLECRY
# 1054             CFM_338            BATTLECRY
# 1055             GVG_097            BATTLECRY
# 1056             GVG_097                TAUNT
# 1057             CFM_852            BATTLECRY
# 1058             LOE_020            BATTLECRY
# 1059             CFM_781              STEALTH
# 1060             GVG_090            BATTLECRY
# 1061             GVG_120            BATTLECRY
# 1062            EX1_055o  TAG_ONE_TURN_EFFECT
# 1063             CFM_321            BATTLECRY
# 1064             EX1_082            BATTLECRY
# 1065             FP1_017                 AURA
# 1066             FP1_001          DEATHRATTLE
# 1067              AT_089              INSPIRE
# 1068             CFM_646          DEATHRATTLE
# 1069              AT_084            BATTLECRY
# 1070             OG_044a               CHARGE
# 1071             OG_044a                TAUNT
# 1072           LOEA09_3d         AI_MUST_PLAY
# 1073            BRMA13_4         AI_MUST_PLAY
# 1074             EX1_009              ENRAGED
# 1075            BRMA10_3         AI_MUST_PLAY
# 1076            NAX3_02H         AI_MUST_PLAY
# 1077             AT_083e  TAG_ONE_TURN_EFFECT
# 1078             CS2_031               FREEZE
#
# [1079 rows x 2 columns]

# %%
play_requirements_df = pd.read_sql_table('play_requirements', engine)

# %%
len(play_requirements_df)
# Out:
# 776

# %%
play_requirements_df
# Out:
#                card_id               play_requirement  value
# 0           KARA_00_07           REQ_NUM_MINION_SLOTS      1
# 1             PRO_001a           REQ_NUM_MINION_SLOTS      1
# 2              NAX1_01           REQ_NUM_MINION_SLOTS      1
# 3          DS1h_292_H1                REQ_STEADY_SHOT      0
# 4          DS1h_292_H1       REQ_MINION_OR_ENEMY_HERO      0
# 5              KAR_076             REQ_TARGET_TO_PLAY      0
# 6               AT_024             REQ_TARGET_TO_PLAY      0
# 7               AT_024           REQ_TARGET_WITH_RACE     15
# 8               AT_024              REQ_MINION_TARGET      0
# 9             BRMA06_2           REQ_NUM_MINION_SLOTS      1
# 10             NAX5_02      REQ_MINIMUM_ENEMY_MINIONS      1
# 11             OG_080c            REQ_FRIENDLY_TARGET      0
# 12             OG_080c             REQ_TARGET_TO_PLAY      0
# 13             OG_080c              REQ_MINION_TARGET      0
# 14             CS2_039             REQ_TARGET_TO_PLAY      0
# 15             CS2_039              REQ_MINION_TARGET      0
# 16   TB_KaraPortal_002              REQ_MINION_TARGET      0
# 17             CS2_094             REQ_TARGET_TO_PLAY      0
# 18     TB_SPT_DPromoHP              REQ_MINION_TARGET      0
# 19            BRMA15_3           REQ_NUM_MINION_SLOTS      1
# 20             CS2_141        REQ_TARGET_IF_AVAILABLE      0
# 21             CS2_141             REQ_NONSELF_TARGET      0
# 22             CS2_063             REQ_TARGET_TO_PLAY      0
# 23             CS2_063              REQ_MINION_TARGET      0
# 24             CS2_063               REQ_ENEMY_TARGET      0
# 25            GVG_055e            REQ_FRIENDLY_TARGET      0
# 26              TB_006             REQ_TARGET_TO_PLAY      0
# 27              TB_006              REQ_MINION_TARGET      0
# 28          CFM_621t21      REQ_MINIMUM_TOTAL_MINIONS      1
# 29          LOEA06_04h             REQ_TARGET_TO_PLAY      0
# ..                 ...                            ...    ...
# 746            GVG_011              REQ_MINION_TARGET      0
# 747            CFM_061             REQ_TARGET_TO_PLAY      0
# 748      AT_132_HUNTER                REQ_STEADY_SHOT      0
# 749      AT_132_HUNTER       REQ_MINION_OR_ENEMY_HERO      0
# 750            GVG_047              REQ_MINION_TARGET      0
# 751            GVG_047               REQ_ENEMY_TARGET      0
# 752            EX1_278             REQ_TARGET_TO_PLAY      0
# 753            CS2_012             REQ_TARGET_TO_PLAY      0
# 754            CS2_012               REQ_ENEMY_TARGET      0
# 755            EX1_578             REQ_TARGET_TO_PLAY      0
# 756            EX1_578              REQ_MINION_TARGET      0
# 757         KARA_00_10  REQ_SECRET_CAP_FOR_NON_SECRET      0
# 758         KARA_13_11      REQ_MINIMUM_ENEMY_MINIONS      2
# 759            GVG_120        REQ_TARGET_IF_AVAILABLE      0
# 760            GVG_120           REQ_TARGET_WITH_RACE     20
# 761         LOEA02_10a           REQ_NUM_MINION_SLOTS      1
# 762            CS1_130             REQ_TARGET_TO_PLAY      0
# 763             AT_025      REQ_MINIMUM_ENEMY_MINIONS      2
# 764            CS2_061             REQ_TARGET_TO_PLAY      0
# 765             AT_084            REQ_FRIENDLY_TARGET      0
# 766             AT_084        REQ_TARGET_IF_AVAILABLE      0
# 767             AT_084              REQ_MINION_TARGET      0
# 768           BRMA16_3            REQ_WEAPON_EQUIPPED      0
# 769           BRMA16_3             REQ_TARGET_TO_PLAY      0
# 770           BRMA16_3              REQ_MINION_TARGET      0
# 771            EX1_624             REQ_TARGET_TO_PLAY      0
# 772             AT_044             REQ_TARGET_TO_PLAY      0
# 773             AT_044              REQ_MINION_TARGET      0
# 774      AT_132_SHAMAN           REQ_NUM_MINION_SLOTS      1
# 775            CS2_031             REQ_TARGET_TO_PLAY      0
#
# [776 rows x 3 columns]

# %%
cards_df.set_index("card_id", inplace=True)

# %%
dust_df.set_index('card_id', inplace=True)

# %%
entourages_df.set_index("card_id", inplace=True)

# %%
mechanics_df.set_index("card_id", inplace=True)

# %%
play_requirements_df.set_index('card_id', inplace=True)

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the dataframes we created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the head of each respective DataFrame to ensure everything worked.
#
#  - NOTE Since we are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %% [markdown]
# ### Executing Joins
#
# Now that we have the tables loaded correctly, we're going to execute some joins. There are 4 different kinds of joins, which can best be visualized with venn diagrams:
#
# <img src='joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table.  The left table is the table we are working with, and the right table is the table we want to join to the table we are working with.  We'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table we want to join with, `mechanics_df`
# * The `how` parameter set to the type of join we want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join("mechanics_df', how ='inner')
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-20-75e711912cb1> in <module>()
# ----> 1 cards_with_mechanics_df = cards_df.join('mechanics_df', how ='inner')
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6334         # For SparseDataFrame's benefit
#    6335         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6336                                  rsuffix=rsuffix, sort=sort)
#    6337
#    6338     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6357             frames = [self] + list(other)
#    6358
# -> 6359             can_concat = all(df.index.is_unique for df in frames)
#    6360
#    6361             # join indexes only using concat
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in <genexpr>(.0)
#    6357             frames = [self] + list(other)
#    6358
# -> 6359             can_concat = all(df.index.is_unique for df in frames)
#    6360
#    6361             # join indexes only using concat
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'is_unique'

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads we displayed earlier.  Notice how it this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, conntains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
#
#
# ### Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = cards_with_mechanics_df.join("play_requirements_df")
left_join_df
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-6-9e65f6fa754d> in <module>()
# ----> 1 left_join_df = cards_with_mechanics_df.join("play_requirements_df")
#       2 left_join_df
#
# NameError: name 'cards_with_mechanics_df' is not defined

# %% [markdown]
# - Note that the results of this sort of join are dependent upon the position of each table--if we were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________
# - Lee's answer - this joined all rows in the left_join_df with the rows in "play_requirements_df" where the primary_ids were found in left_join_df
#
#
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = None
outer_join_df

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, we learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Use `sqlalchemy` to connect to a sqlite database and read in individual tables as DataFrames
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
